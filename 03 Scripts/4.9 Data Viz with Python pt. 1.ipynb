# %% [markdown]
# # 4.9 Data Viz with Python pt. 1

# %% [markdown]
# # 3. Import Libraries and Customer Data Set

# %%
#Import libraries - pandas, Numpy, OS
import pandas as pd
import numpy as np
import os

# %%
#Creating a path to the root directory for this project
path = r'C:\Users\theva\OneDrive\CareerFoundry\Data Immersion\A4\Instacart Basket Analysis 11-2022'

# %%
#Importing customers.csv to df via pandas.read_csv and os.path.join
df_cust = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'customers.csv'), index_col = False)

# %% [markdown]
# # 4. Data Wrangling

# %%
df_cust.shape
# Out:
# (206209, 10)

# %%
pd.options.display.max_rows = 100

# %%
df_cust.head(100)
# Out:
#     user_id   First Name     Surnam  Gender                 STATE  Age  \
# 0     26711      Deborah   Esquivel  Female              Missouri   48
# 1     33890     Patricia       Hart  Female            New Mexico   36
# 2     65803      Kenneth     Farley    Male                 Idaho   35
# 3    125935     Michelle      Hicks  Female                  Iowa   40
# 4    130797          Ann    Gilmore  Female              Maryland   26
# 5    133128      Cynthia      Noble  Female              Kentucky   43
# 6    152052        Chris     Walton    Male               Montana   20
# 7    168851       Joseph    Hickman    Male        South Carolina   30
# 8     69965       Jeremy       Vang    Male                 Texas   47
# 9     82820        Shawn      Chung    Male              Virginia   26
# 10    26441       Gloria   Stafford  Female                Nevada   19
# 11    33835        Roger      Casey    Male              Nebraska   45
# ...

# %%
df_cust.tail(20)
# Out:
#         user_id   First Name      Surnam  Gender           STATE  Age  \
# 206189   193828      Russell      Travis    Male  North Carolina   46
# 206190   197067        Kathy        Bell  Female         Arizona   42
# 206191     7177      Russell   Zimmerman    Male     Mississippi   71
# 206192    61888       Joshua      Guerra    Male      New Jersey   37
# 206193   103412       Willie     Goodman    Male        Michigan   46
# 206194   189337        Shawn        Wood    Male      New Jersey   56
# 206195   205766       Amanda       Hodge  Female          Oregon   18
# 206196   139950       Gloria      Murray  Female        Colorado   45
# 206197    74598  Christopher   Velazquez    Male       Minnesota   52
# 206198    83573       Gloria      Murray  Female        Michigan   28
# 206199   179673         Adam  Villanueva    Male         Wyoming   77
# 206200   192637        Kelly    Petersen  Female         Florida   47
# ...

# %% [markdown]
# Notes: 'First Name', 'Surnam', and 'date_joined' are not needed for the analysis

# %% [markdown]
# ### Dropping unnecessary columns

# %%
#dropping unecessary columns
df_cust = df_cust.drop(columns = ['First Name', 'Surnam', 'date_joined'])

# %%
df_cust.shape
# Out:
# (206209, 7)

# %% [markdown]
# ### Making column names unifrom and unambiguous

# %%
#Checking Changes
df_cust.columns
# Out:
# Index(['user_id', 'Gender', 'STATE', 'Age', 'n_dependants', 'fam_status',
#        'income'],
#       dtype='object')

# %% [markdown]
# Notes: Change column names Gender to gender, STATE to state, Age to age, n_dependants to num_dependants

# %%
#Changing column names
df_cust = df_cust.rename(columns = {'Gender' : 'gender', 'STATE' : 'state', 'Age' : 'age', 'n_dependants' : 'num_dependants'})

# %%
#Checking Changes
df_cust.columns
# Out:
# Index(['user_id', 'gender', 'state', 'age', 'num_dependants', 'fam_status',
#        'income'],
#       dtype='object')

# %% [markdown]
# ### Changing data types

# %%
df_cust.dtypes
# Out:
# user_id            int64
# gender            object
# state             object
# age                int64
# num_dependants     int64
# fam_status        object
# income             int64
# dtype: object

# %% [markdown]
# Notes: Change user_id to str, date_joined to datetime

# %%
#Changing user_id data type to string
df_cust = df_cust.astype({'user_id': str})

# %%
df_cust.dtypes
# Out:
# user_id           object
# gender            object
# state             object
# age                int64
# num_dependants     int64
# fam_status        object
# income             int64
# dtype: object

# %% [markdown]
# # 5. Data Quality and Consistency

# %% [markdown]
# ### Spread

# %%
#Checking spread
df_cust.describe()
# Out:
#                  age  num_dependants         income
# count  206209.000000   206209.000000  206209.000000
# mean       49.501646        1.499823   94632.852548
# std        18.480962        1.118433   42473.786988
# min        18.000000        0.000000   25903.000000
# 25%        33.000000        0.000000   59874.000000
# 50%        49.000000        1.000000   93547.000000
# 75%        66.000000        3.000000  124244.000000
# max        81.000000        3.000000  593901.000000

# %% [markdown]
# Notes: All values seem to be within a healthy range

# %%
#Checking distribution of income since max is several std larger than mean
df_cust.plot.scatter('income', 'income')
# Out:
# <AxesSubplot:xlabel='income', ylabel='income'>

# %% [markdown]
# Notes: All values seem to be within a healthy range

# %% [markdown]
# ### Mixed data types

# %%
#Check for mixed data types
for col in df_cust.columns.tolist():
  weird = (df_cust[[col]].applymap(type) != df_cust[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_cust[weird]) > 0:
    print (col, ' mixed')
  else: print(col, ' consistent')
# Out:
# user_id  consistent
# gender  consistent
# state  consistent
# age  consistent
# num_dependants  consistent
# fam_status  consistent
# income  consistent

# %% [markdown]
# Notes: All consistent.

# %% [markdown]
# ### Missing Values

# %%
#Count the missing values in each col
df_cust.isnull().sum()
# Out:
# user_id           0
# gender            0
# state             0
# age               0
# num_dependants    0
# fam_status        0
# income            0
# dtype: int64

# %% [markdown]
# Notes: No missing values.

# %% [markdown]
# ### Duplicates

# %%
#Checking count of duplicate rows
df_cust.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Notes: No duplicated values.

# %% [markdown]
# # 6. Combine with main data set

# %% [markdown]
# ### Organizing dataframes

# %%
#Importing ords_prods_agged
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_agged.pkl'))

# %%
#Changing 5127 anomalous prices into NaN
ords_prods_merge.loc[ords_prods_merge['prices'] >100, 'prices'] = np.nan

# %%
#Check results max and count of NaN
ords_prods_merge['prices'].max(), ords_prods_merge['prices'].isnull().sum()
# Out:
# (25.0, 5127)

# %%
#Changing anomalous (> 100) days_since_prior_order into NaN
ords_prods_merge.loc[ords_prods_merge['days_since_prior_order'] >100, 'days_since_prior_order'] = np.nan

# %%
#Check results max and count of NaN
ords_prods_merge['days_since_prior_order'].max(), ords_prods_merge['days_since_prior_order'].isnull().sum()
# Out:
# (30.0, 2076096)

# %% [markdown]
# ### Shape and key checks

# %%
#Checking shape
ords_prods_merge.shape
# Out:
# (32404859, 23)

# %%
#Checking shape
df_cust.shape
# Out:
# (206209, 7)

# %%
#Checking data type of key
ords_prods_merge['user_id'].dtype
# Out:
# dtype('int64')

# %%
#Checking data type of key
df_cust['user_id'].dtype
# Out:
# dtype('O')

# %%
#Changing data type of df_cust user_id to int64
df_cust = df_cust.astype({'user_id': 'int64'})

# %%
#Checking data type of key
df_cust['user_id'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# ### Merging

# %%
#Merging ords_prods_merge with df_cust
ords_prods_cust = ords_prods_merge.merge(df_cust, on = 'user_id', indicator = True)

# %%
ords_prods_cust.shape
# Out:
# (32404859, 30)

# %%
#Checking merge structure
ords_prods_cust.head(20)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# 5    3367565        1             6                   2                  7
# 6     550135        1             7                   1                  9
# 7    3108588        1             8                   1                 14
# 8    2295261        1             9                   1                 16
# 9    2550362        1            10                   4                  8
# 10   2539329        1             1                   2                  8
# ...

# %%
#Checking merge structure
ords_prods_cust.tail(20)
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 32404839    634152   106143            11                   4
# 32404840   1977554   106143            12                   3
# 32404841   1806098   106143            13                   2
# 32404842    131426   106143            14                   6
# 32404843   2267896   106143            15                   0
# 32404844   1987169   106143            16                   6
# 32404845   3143166   106143            17                   0
# 32404846   3094081   106143            18                   4
# 32404847    405982   106143            19                   3
# 32404848   3102310   106143            20                   3
# 32404849   1539810   106143            21                   1
# 32404850   3308056   106143            22                   4
# 32404851   2988973   106143            23                   2
# 32404852       930   106143            24                   6
# ...

# %%
#Checking merge counts
ords_prods_cust['_merge'].value_counts(dropna = False)
# Out:
# both          32404859
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
#dropping _merge column
ords_prods_cust = ords_prods_cust.drop(columns = ['_merge'])

# %%
ords_prods_cust.shape
# Out:
# (32404859, 29)

# %% [markdown]
# Notes: Merge successful.

# %% [markdown]
# # 8. Export merged dataframe

# %%
#Export df_merged_large
ords_prods_cust.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_customers.pkl'))
