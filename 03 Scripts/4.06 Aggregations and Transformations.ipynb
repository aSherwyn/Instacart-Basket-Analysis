# %% [markdown]
# # 4.06: Aggregations and Transformations
# #### 01. Importing Libraries
# #### 02. Importing Data
# #### 03. Aggregation Explorations
# #### 04. Transformation Explorations
# #### 05. Spending Flag
# #### 06. Order Frequency Flag

# %% [markdown]
# # 01. Importing Libraries

# %%
#Import libraries - pandas, Numpy, OS
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Importing Data

# %%
#Creating a path to the root directory for this project
path = r'C:\Users\theva\OneDrive\CareerFoundry\Data Immersion\A4\Instacart Basket Analysis 11-2022'

# %%
#Importing orders_products_merged.pkl as df_op_merged
ords_prods_merge  = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_extended.pkl'))

# %%
ords_prods_merge.shape
# Out:
# (32404859, 17)

# %% [markdown]
# # 03. Aggregation Explorations

# %%
#Group and apply a SINGLE aggregate
df_subset = df.groupby('department_id').agg({'order_number': ['mean']})

# %%
df_subset
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %%
#Alternate aggregating method 1
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 4     18.825780
# 7     17.472355
# 13    17.993423
# 14    19.246334
# 16    19.463012
# 17    11.294069
# 19    19.305237
# 20    17.599636
# Name: order_number, dtype: float64

# %%
#Alternate aggregating method 2
df.groupby('department_id').order_number.mean()
# Out:
# department_id
# 4     18.825780
# 7     17.472355
# 13    17.993423
# 14    19.246334
# 16    19.463012
# 17    11.294069
# 19    19.305237
# 20    17.599636
# Name: order_number, dtype: float64

# %%
#Group and apply MULTIPLE aggregates
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 4                18.825780   1  99
# 7                17.472355   1  99
# 13               17.993423   1  99
# 14               19.246334   1  99
# 16               19.463012   1  99
# 17               11.294069   1  98
# 19               19.305237   1  99
# 20               17.599636   1  99

# %% [markdown]
# # 04. Transformation Explorations

# %%
df.describe()
# Out:
#            order_id         user_id    order_number  orders_day_of_week  \
# count  1.000000e+06  1000000.000000  1000000.000000      1000000.000000
# mean   1.710240e+06   101788.547547       18.731714            2.686741
# std    9.873682e+05    59011.894306       18.563841            2.053382
# min    5.000000e+00        1.000000        1.000000            0.000000
# 25%    8.555392e+05    50641.000000        5.000000            1.000000
# 50%    1.709734e+06   101164.000000       12.000000            2.000000
# 75%    2.565079e+06   152132.000000       27.000000            5.000000
# max    3.421068e+06   206209.000000       99.000000            6.000000
#
#        order_hour_of_day  days_since_prior_order      product_id  \
# count     1000000.000000          1000000.000000  1000000.000000
# mean           13.272235               70.031595    27119.966748
# std             4.218017              235.020089    15578.819637
# ...

# %% [markdown]
# #### Creating a Loyalty flag based on number of orders per user

# %%
#Create a 'max_order' variable in ords_prods_merge to signify the max order per user_id
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
# Checking results
ords_prods_merge.head(20)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# 5    3367565        1             6                   2                  7
# 6     550135        1             7                   1                  9
# 7    3108588        1             8                   1                 14
# 8    2295261        1             9                   1                 16
# 9    2550362        1            10                   4                  8
# 10   2968173       15            15                   1                  9
# ...

# %%
# Making Loyal customer val in 'loyalty_flag' col based on transformation results
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
# Making Regular customer val in 'loyalty_flag' col based on transformation results
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
# Making New customer val in 'loyalty_flag' col based on transformation results
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
#Checking loyalty_flag results
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
#limited .head() check
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             2
# 2         1      New customer             3
# 3         1      New customer             4
# 4         1      New customer             5
# 5         1      New customer             6
# 6         1      New customer             7
# 7         1      New customer             8
# 8         1      New customer             9
# 9         1      New customer            10
# 10       15  Regular customer            15
# 11       15  Regular customer            17
# 12       15  Regular customer            18
# 13       15  Regular customer            21
# 14       15  Regular customer            22
# 15       19      New customer             2
# 16       19      New customer             5
# 17       19      New customer             7
# 18       21  Regular customer            10
# 19       31  Regular customer            10
# ...

# %% [markdown]
# # 06. Task

# %% [markdown]
# #### Prep: dropping rows with 'prices' of 99999 and 'days_since_prior_order' of 999 for summary stats

# %%
#Copying ords_prods_merge for safety
ords_prods_2 = ords_prods_merge

# %%
#Removing rows with prices == 99999
ords_prods_2 = ords_prods_2.drop(ords_prods_2[ords_prods_2['prices'] == 99999].index)

# %%
#Checking original shape
ords_prods_merge.shape

# %%
#Checking new shape
ords_prods_2.shape

# %% [markdown]
# Success

# %%
#Removing rows with 'days_since_prior_order' = 999
ords_prods_2 = ords_prods_2.drop(ords_prods_2[ords_prods_2['days_since_prior_order'] == 999].index)

# %%
#Checking new shape
ords_prods_2.shape

# %% [markdown]
# Success

# %%
#Export modified df to save memory
ords_prods_2.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_extended2.pkl'))

# %%
#Import modified df
#Importing orders_products_merged.pkl as df_op_merged
ords_prods_2  = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_extended2.pkl'))

# %% [markdown]
# ### Aggregated mean of the “order_number” column grouped by “department_id”

# %%
#Grouping by department_id and aggregating by mean of order_number
ords_prods_2.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                16.559358
# 2                18.413176
# 3                18.279600
# 4                18.915890
# 5                16.497751
# 6                17.609390
# 7                18.303975
# 8                16.383301
# 9                17.022963
# 10               21.227447
# 11               17.311768
# 12               16.953613
# 13               17.727470
# 14               17.898097
# 15               17.290123
# 16               18.760065
# 17               16.808683
# 18               20.336389
# 19               18.258620
# 20               17.578959
# 21               23.644477

# %% [markdown]
# ### Basic statistics of the product prices for each loyalty category.

# %%
#Group by loyalty category and apply mean, median, min, max aggregates
ords_prods_2.groupby('loyalty_flag').agg({'prices': ['mean', 'median', 'min', 'max']})
# Out:
#                     prices
#                       mean median  min   max
# loyalty_flag
# Loyal customer    7.774068    7.4  1.0  25.0
# New customer      7.802315    7.4  1.0  25.0
# Regular customer  7.799374    7.4  1.0  25.0

# %% [markdown]
# # 05. Spending Flag
# Criteria:
# </br>High spender >= 10
# </br>Low spender < 10

# %%
#Create a 'mean_price' variable to signify the mean price per user_id
ords_prods_2['mean_price'] = ords_prods_2.groupby(['user_id'])['prices'].transform(np.mean)

# %%
#Checking results
ords_prods_2.shape
# Out:
# (30323987, 20)

# %%
#Checking results
ords_prods_2.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
# 5   3367565        1             6                   2                  7
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
# 5                    19.0         196                  1          1
#
#   product_name  ...    price_range_loc     busiest_day    busy_days  \
# ...

# %%
#Checking 'mean_price' min, max, and mean
ords_prods_2['mean_price'].min(),ords_prods_2['mean_price'].max(), ords_prods_2['mean_price'].mean()
# Out:
# (1.0, 23.2, 7.791449577522142)

# %%
# Making 'High spender' val in 'spender_flag' col based on transformation results
ords_prods_2.loc[ords_prods_2['mean_price'] >= 10, 'spender_flag'] = 'High spender'

# %%
# Making 'Low spender' val in 'spender_flag' col based on transformation results
ords_prods_2.loc[ords_prods_2['mean_price'] < 10, 'spender_flag'] = 'Low spender'

# %%
#Checking results
ords_prods_2.shape
# Out:
# (30323987, 21)

# %%
#Checking results
ords_prods_2[['user_id', 'mean_price', 'spender_flag']].tail(60)
# Out:
#           user_id  mean_price  spender_flag
# 32404788   194719    7.743478   Low spender
# 32404789   181634    8.823358   Low spender
# 32404790   202619    7.743750   Low spender
# 32404791   181905    7.537179   Low spender
# 32404792   181978    7.265385   Low spender
# 32404793   204148    8.659639   Low spender
# 32404795   182190    7.542574   Low spender
# 32404797   204229    7.951172   Low spender
# 32404798   204472    7.971631   Low spender
# 32404799   183369    7.651169   Low spender
# 32404800   183369    7.651169   Low spender
# 32404801   183867    8.198931   Low spender
# 32404803   186019    7.924766   Low spender
# 32404804   198888    8.412051   Low spender
# 32404805   186019    7.924766   Low spender
# 32404806   186227    7.493075   Low spender
# 32404807   186321   14.133333  High spender
# 32404808   186870    8.505650   Low spender
# 32404809   186870    8.505650   Low spender
# 32404810   186419    6.947363   Low spender
# ...

# %%
#Checking spender_flag frequencies
ords_prods_2['spender_flag'].value_counts(dropna = False)
# Out:
# Low spender     30202910
# High spender      121077
# Name: spender_flag, dtype: int64

# %% [markdown]
# # 06. Order Frequency Flag
# Criteria:
# </br>Non-frequent customer > 20
# </br>Regular customer <= 20 & > 10
# </br>Frequent customer <= 10

# %%
#Create a 'median_order_frequency' variable to signify the median 'days_since_prior_order' per user_id
ords_prods_2['median_order_frequency'] = ords_prods_2.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
#Checking results
ords_prods_2.shape
# Out:
# (30323987, 22)

# %%
#Checking results
ords_prods_2.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
# 5   3367565        1             6                   2                  7
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
# 5                    19.0         196                  1          1
#
#   product_name  ...  prices    price_range_loc     busiest_day    busy_days  \
# ...

# %%
#Checking 'median_order_frequency' min, max, and mean
ords_prods_2['median_order_frequency'].min(),ords_prods_2['median_order_frequency'].max(), ords_prods_2['median_order_frequency'].mean()
# Out:
# (0.0, 30.0, 10.087923596590382)

# %%
# Making 'Non-frequent customer' val in 'order_frequency_flag' col based on transformation results
ords_prods_2.loc[ords_prods_2['median_order_frequency'] > 20, 'order_frequency_flag'] = 'Non-frequent customer'

# %%
# Making 'Regular customer' val in 'order_frequency_flag' col based on transformation results
ords_prods_2.loc[(ords_prods_2['median_order_frequency'] <= 20) & (ords_prods_2['median_order_frequency'] > 10), 'order_frequency_flag'] = 'Regular customer'

# %%
# Making 'Frequent customer' val in 'order_frequency_flag' col based on transformation results
ords_prods_2.loc[ords_prods_2['median_order_frequency'] <= 10, 'order_frequency_flag'] = 'Frequent customer'

# %%
#Checking results
ords_prods_2.shape
# Out:
# (30323987, 23)

# %%
ords_prods_2[['user_id', 'median_order_frequency', 'order_frequency_flag']].head(60)
# Out:
#     user_id  median_order_frequency   order_frequency_flag
# 1         1                    20.5  Non-frequent customer
# 2         1                    20.5  Non-frequent customer
# 3         1                    20.5  Non-frequent customer
# 4         1                    20.5  Non-frequent customer
# 5         1                    20.5  Non-frequent customer
# 6         1                    20.5  Non-frequent customer
# 7         1                    20.5  Non-frequent customer
# 8         1                    20.5  Non-frequent customer
# 9         1                    20.5  Non-frequent customer
# 10       15                    10.0      Frequent customer
# 11       15                    10.0      Frequent customer
# 12       15                    10.0      Frequent customer
# 13       15                    10.0      Frequent customer
# 14       15                    10.0      Frequent customer
# 15       19                     6.0      Frequent customer
# ...

# %%
#Checking order_frequency_flag frequencies
ords_prods_2['order_frequency_flag'].value_counts(dropna = False)
# Out:
# Frequent customer        20672217
# Regular customer          6593424
# Non-frequent customer     3058346
# Name: order_frequency_flag, dtype: int64

# %% [markdown]
# ### Export

# %%
#Export modified df to save memory
ords_prods_2.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_grouped.pkl'))
